# %%
import numpy as np
import scipy
import matplotlib.pyplot as plt
from importlib import reload

import train as t
import model
import loss
import utils

# %%
reload(utils)
# Out:
# <module 'utils' from '/users/invites/jmorlot/Documents/Projects/Seq2Seq_Nucleosom/utils.py'>

# %%
reload(model)
# Out:
# <module 'model' from '/users/invites/jmorlot/Documents/Projects/Seq2Seq_Nucleosom/model.py'>

# %%
reload(t)
# Out:
# <module 'train' from '/users/invites/jmorlot/Documents/Projects/Seq2Seq_Nucleosom/train.py'>

# %%
s2s = t.Seq2Seq_model(fasta_path='Nucleosom_data/Reference sequence-chrI-1..230218.fasta',
                      histone_path='Nucleosom_data/Chereji_2018_Occupancy_H3_CC_V64-chrI-1..230218.bedgraph',
                      output_size=1,
                      Nepochs=10,
                      seq_len=5000,
                      batchsize=1,
                      hidden_size=8,
                      input_dropout_p=0,
                      n_layers=1,
                      use_cuda=True)

# %%
s2s.fit()
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# train:   0%|          | 0/36 [00:00<?, ?it/s]Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/queues.py", line 240, in _feed
#     send_bytes(obj)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/queues.py", line 240, in _feed
#     send_bytes(obj)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/queues.py", line 240, in _feed
#     send_bytes(obj)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/queues.py", line 240, in _feed
#     send_bytes(obj)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/queues.py", line 240, in _feed
#     send_bytes(obj)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/queues.py", line 240, in _feed
#     send_bytes(obj)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/queues.py", line 240, in _feed
#     send_bytes(obj)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/queues.py", line 240, in _feed
#     send_bytes(obj)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/queues.py", line 240, in _feed
#     send_bytes(obj)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/queues.py", line 240, in _feed
#     send_bytes(obj)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/queues.py", line 240, in _feed
#     send_bytes(obj)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/queues.py", line 240, in _feed
#     send_bytes(obj)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/queues.py", line 240, in _feed
#     send_bytes(obj)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/queues.py", line 240, in _feed
#     send_bytes(obj)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/queues.py", line 240, in _feed
#     send_bytes(obj)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/queues.py", line 240, in _feed
#     send_bytes(obj)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/queues.py", line 240, in _feed
#     send_bytes(obj)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/queues.py", line 240, in _feed
#     send_bytes(obj)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/queues.py", line 240, in _feed
#     send_bytes(obj)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/queues.py", line 240, in _feed
#     send_bytes(obj)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/queues.py", line 240, in _feed
#     send_bytes(obj)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/queues.py", line 240, in _feed
#     send_bytes(obj)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/queues.py", line 240, in _feed
#     send_bytes(obj)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/queues.py", line 240, in _feed
#     send_bytes(obj)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/queues.py", line 240, in _feed
#     send_bytes(obj)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/queues.py", line 240, in _feed
#     send_bytes(obj)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/queues.py", line 240, in _feed
#     send_bytes(obj)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/queues.py", line 240, in _feed
#     send_bytes(obj)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/queues.py", line 240, in _feed
#     send_bytes(obj)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/queues.py", line 240, in _feed
#     send_bytes(obj)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
#   File "/users/invites/jmorlot/anaconda2/envs/GPU/lib/python3.6/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
# BrokenPipeError: [Errno 32] Broken pipe
# BrokenPipeError: [Errno 32] Broken pipe
# BrokenPipeError: [Errno 32] Broken pipe
# BrokenPipeError: [Errno 32] Broken pipe
# BrokenPipeError: [Errno 32] Broken pipe
# BrokenPipeError: [Errno 32] Broken pipe
# BrokenPipeError: [Errno 32] Broken pipe
# BrokenPipeError: [Errno 32] Broken pipe
# BrokenPipeError: [Errno 32] Broken pipe
# BrokenPipeError: [Errno 32] Broken pipe
# BrokenPipeError: [Errno 32] Broken pipe
# BrokenPipeError: [Errno 32] Broken pipe
# BrokenPipeError: [Errno 32] Broken pipe
# BrokenPipeError: [Errno 32] Broken pipe
# BrokenPipeError: [Errno 32] Broken pipe
# BrokenPipeError: [Errno 32] Broken pipe
# BrokenPipeError: [Errno 32] Broken pipe
# BrokenPipeError: [Errno 32] Broken pipe
# BrokenPipeError: [Errno 32] Broken pipe
# BrokenPipeError: [Errno 32] Broken pipe
# BrokenPipeError: [Errno 32] Broken pipe
# BrokenPipeError: [Errno 32] Broken pipe
# BrokenPipeError: [Errno 32] Broken pipe
# BrokenPipeError: [Errno 32] Broken pipe
# BrokenPipeError: [Errno 32] Broken pipe
# BrokenPipeError: [Errno 32] Broken pipe
# BrokenPipeError: [Errno 32] Broken pipe
# BrokenPipeError: [Errno 32] Broken pipe
# BrokenPipeError: [Errno 32] Broken pipe
# BrokenPipeError: [Errno 32] Broken pipe
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-eca35ddcfc7a> in <module>()
# ----> 1 s2s.fit()
#
# ~/Documents/Projects/Seq2Seq_Nucleosom/train.py in fit(self)
#     114
#     115                 self.foreward()
# --> 116                 self.backward()
#     117                 self.record_loss()
#     118                 self.tensorboard()
#
# ~/Documents/Projects/Seq2Seq_Nucleosom/train.py in backward(self)
#     123     def backward(self):
#     124         self.compute_loss()
# --> 125         self.S2S_loss.backward()
#     126         self.optim.step()
#     127
#
# ~/anaconda2/envs/GPU/lib/python3.6/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     100                 products. Defaults to ``False``.
#     101         """
# --> 102         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     103
#     104     def register_hook(self, hook):
#
# ~/anaconda2/envs/GPU/lib/python3.6/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      88     Variable._execution_engine.run_backward(
#      89         tensors, grad_tensors, retain_graph, create_graph,
# ---> 90         allow_unreachable=True)  # allow_unreachable flag
#      91
#      92
#
# KeyboardInterrupt:
